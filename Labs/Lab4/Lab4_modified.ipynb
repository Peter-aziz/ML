# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-aziz/ML/blob/main/Labs/Lab4/Lab4_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Text Generation with RNNs
#
# In this assignment, you will explore text generation using deep learning models, specifically Recurrent Neural Networks (RNNs). Text generation is a fascinating task where the goal is to train a model that can predict the next word in a sequence, ultimately generating coherent and contextually accurate sentences or paragraphs.
#
# You will work with a corpus of text data provided in the tutorial (from TensorFlow), which contains a large collection of Shakespeare’s works. Your objective is to implement a text generation model using RNNs and to evaluate its performance based on various metrics.
#
# <img src="https://drek4537l1klr.cloudfront.net/teofili2/Figures/03fig09_alt.jpg" alt="Drawing"/>
#
# **The models include:**
# - Deep RNN (LSTM)
# - Deep RNN (GRU)
# - Bidirectional RNN
#
#
# **Evaluation:**
#
# Evaluate the performance of the text generation model using several metrics:
# - Perplexity: A measure of how well the probability distribution predicted by the model aligns with the actual distribution of words in the text.
# - Generated Text Quality: Subjectively evaluate the quality of the generated text by considering grammar, coherence, and creativity. This can be done by visually inspecting the generated sequences.
# - BLUE Score: Character-level BLEU: BLEU can be applied at the character level by treating each character as an n-gram. This is particularly useful when the task involves generating character sequences (like poetry, code, or fine-grained character-based generation).
# For example, the sequence “hello” could be evaluated by comparing 1-grams (e.g., “h”, “e”, “l”, “l”, “o”) or higher-order n-grams (e.g., “he”, “el”, “ll”, “lo”).
#
# **Goals:**
#
# - Compare the performance of GRU and LSTM. Is there a significant difference in the results?
# - Compare the performance of the unidirectional and bidirectional RNN models.
# Which model produces better results?
# - Discuss the impact of bidirectional RNNs on text generation tasks.

# %% [markdown]
# # Import TensorFlow and other libraries

# %%
import tensorflow as tf
import numpy as np
import nltk
from nltk.translate.bleu_score import sentence_bleu
import os
import time

# %% [markdown]
# # Dataset

# %% [markdown]
# The Shakespeare dataset used for text generation contains a collection of works by William Shakespeare, primarily in the form of plays and sonnets. The text is used to train language models, offering an ideal example for character-level modeling due to its rich, complex language. The dataset is often preprocessed by tokenizing it into individual characters, enabling models to learn the sequential relationships between characters for generating coherent and contextually appropriate text.
#
# To access the dataset, you can use TensorFlow's get_file method as follow:
#
# You can inspect the dataset on [Kaggle](https://www.kaggle.com/datasets/adarshpathak/shakespeare-text/data).

# %%
path_to_file = tf.keras.utils.get_file('shakespeare.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')

# Read, then decode for py2 compat.
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
# length of text is the number of characters in it
print(f'Length of text: {len(text)} characters')
# Out:
# Length of text: 1115394 characters

# %%
# Take a look at the first 250 characters in text
print(text[:250])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.

# %% [markdown]
# # Process the text

# %% [markdown]
# ### Vectorize the text
#
# Before training, you need to convert the strings to a numerical representation.
#
# The `tf.keras.layers.StringLookup` layer can convert each character into a numeric ID. It just needs the text to be split into tokens first.

# %%
example_texts = ['abcdefg', 'xyz']

chars = tf.strings.unicode_split(example_texts, input_encoding='UTF-8')
chars
# Out:
# <tf.RaggedTensor [[b'a', b'b', b'c', b'd', b'e', b'f', b'g'], [b'x', b'y', b'z']]>

# %% [markdown]
# Now create the [`tf.keras.layers.StringLookup`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/StringLookup) layer:
#
# Since the goal of this assignment is to generate text, it will also be important to invert this representation and recover human-readable strings from it. For this you can use tf.keras.layers.StringLookup(..., invert=True).
#
# Note: Here instead of passing the original vocabulary generated with sorted(set(text)) use the get_vocabulary() method of the tf.keras.layers.StringLookup layer so that the [UNK] tokens is set the same way.

# %%
def get_string_lookup_layers(vocab):
    """
    Creates StringLookup layers for encoding characters to IDs and decoding IDs back to characters.

    Args:
        vocab (list): List of unique characters in the dataset.

    Returns:
        ids_from_chars (tf.keras.layers.StringLookup): Converts characters to IDs.
        chars_from_ids (tf.keras.layers.StringLookup): Converts IDs back to characters.
    """
    ids_from_chars = tf.keras.layers.StringLookup(vocabulary=list(vocab), mask_token=None)
    chars_from_ids = tf.keras.layers.StringLookup(vocabulary=ids_from_chars.get_vocabulary(), invert=True, mask_token=None)
    return ids_from_chars, chars_from_ids

# %%
def text_from_ids(ids, chars_from_ids):
    """
    Converts a sequence of character IDs into a human-readable string.

    Args:
        ids (tf.Tensor): Tensor of character IDs.
        chars_from_ids (tf.keras.layers.StringLookup): StringLookup layer to decode IDs.

    Returns:
        tf.Tensor: Decoded string.
    """
    return tf.strings.reduce_join(chars_from_ids(ids), axis=-1)

# %% [markdown]
# # Create training examples and targets

# %% [markdown]
# Next divide the text into example sequences. Each input sequence will contain seq_length characters from the text.
#
# For each input sequence, the corresponding targets contain the same length of text, except shifted one character to the right.
#
# So break the text into chunks of seq_length+1. For example, say seq_length is 4 and our text is "Hello". The input sequence would be "Hell", and the target sequence "ello".
#
# To do this first use the tf.data.Dataset.from_tensor_slices function to convert the text vector into a stream of character indices.

# %% [markdown]
# For training you'll need a dataset of (input, label) pairs. Where input and label are sequences. At each time step the input is the current character and the label is the next character.
#
# Here's a function that takes a sequence as input, duplicates, and shifts it to align the input and label for each timestep:

# %%
def split_input_target(sequence):
    input_text = sequence[:-1]
    target_text = sequence[1:]
    return input_text, target_text

# %% [markdown]
# Convert Text to Numerical Sequences

# %%
# Initialize mapping layers
vocab = sorted(set(text))
ids_from_chars, chars_from_ids = get_string_lookup_layers(vocab)



# Convert text to character IDs
all_ids = ids_from_chars(tf.strings.unicode_split(text, 'UTF-8'))

# Create a dataset from the character IDs
ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)

# %% [markdown]
# Create Sequences for Training

# %%
seq_length = 100  # Length of each training sequence

# Batch sequences (each sequence is seq_length + 1)
sequences = ids_dataset.batch(seq_length + 1, drop_remainder=True)

# Map dataset to input-target format
dataset = sequences.map(split_input_target)

# Print sample input-output pairs
for input_example, target_example in dataset.take(1):
    print("Input :", tf.strings.reduce_join(chars_from_ids(input_example)).numpy().decode('utf-8'))
    print("Target:", tf.strings.reduce_join(chars_from_ids(target_example)).numpy().decode('utf-8'))
# Out:
# Input : First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You
# Target: irst Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %% [markdown]
# # Create RNN Models

# %% [markdown]
# Before training our text generation models, we need to set up key parameters and prepare the dataset. These parameters control the size of batches, buffer size for shuffling, embedding dimensions, and the number of units in the recurrent layer.

# %% [markdown]
# Customizing Parameters for Optimization
#
# - Increase RNN_UNITS if the model is underfitting (not capturing enough detail).
# - Decrease BATCH_SIZE if memory usage is too high (e.g., when using large RNN units).
# - Adjust EMBEDDING_DIM to experiment with the quality of learned character representations.
#
# Tip: Start with these values, then fine-tune based on model performance and available computational resources!

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000
VOCAB_SIZE = len(vocab) + 1
DATASET_SIZE = sum(1 for _ in dataset)

shuffled_dataset = dataset.shuffle(BUFFER_SIZE)

train_dataset = shuffled_dataset.take(int(0.9 * DATASET_SIZE) )
val_dataset = shuffled_dataset.skip(int(0.1 * DATASET_SIZE) )

# Prepare dataset for training
training_dataset = (train_dataset
                 .batch(BATCH_SIZE, drop_remainder=True)
                 .prefetch(tf.data.experimental.AUTOTUNE))
# Prepare dataset for validation
validation_dataset = (val_dataset
               .batch(BATCH_SIZE, drop_remainder=True)
               .prefetch(tf.data.experimental.AUTOTUNE))

# %% [markdown]
# # LSTM-Based Model

# %% [markdown]
# Long Short-Term Memory (LSTM) is a type of Recurrent Neural Network (RNN) designed to capture long-range dependencies in sequential data. Unlike traditional RNNs, which struggle with vanishing gradients, LSTMs use gates (input, forget, and output gates) to regulate the flow of information, making them highly effective for text generation tasks.
#
# This function defines an LSTM-based neural network for text generation.
#
# **Function Overview:**
# * [`tf.keras.layers.Embedding`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding): This is the input layer, consisting of a trainable lookup table that maps the numbers of each character to a vector with `embedding_dim` dimensions.
# * [`tf.keras.layers.LSTM`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM): Our LSTM network, with size `units=rnn_units`.
# * [`tf.keras.layers.Dense`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense): The output layer, with `vocab_size` outputs.
#
#
# <img src="https://raw.githubusercontent.com/aamini/introtodeeplearning/2019/lab1/img/lstm_unrolled-01-01.png" alt="Drawing"/>

# %%
def build_lstm_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# **Customization & Optimization**
#
# These experiments are required to improve model performance. You must conduct the following experiments and document your findings:
#
# - Increase RNN_UNITS : This enhances the model’s ability to recognize deeper patterns but may increase training time.
# - Experiment with EMBEDDING_DIM : Adjusting this can improve the quality of character representation.
# - Stack multiple LSTM layers : This can help the model understand text more effectively.
#
# **Submission Requirements**
#
# - Perform at least three trials varying the parameters above.
# - Keep the most performing plots and outputs in your Jupyter Notebook.

# %% [markdown]
# # GRU-Based Model

# %% [markdown]
# What is GRU?
#
# Gated Recurrent Units (GRU) are a simplified version of LSTMs that combine the forget and input gates into a single update gate. This makes GRUs:
#
# - Faster and more efficient than LSTMs
# - Perform well on shorter sequences
# - Require fewer computational resources
#
# **Model Comparison (LSTM vs. GRU)**
#
# To evaluate the differences between LSTM and GRU models, compare them using:
#
# - Model Size & Number of Parameters : Use model.summary() to check the number of trainable parameters in each model.
# - Training Speed & Efficiency : Measure training time per epoch for both models.

# %%
def build_gru_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# # Bidirectional Model
#
#
# <img src="https://www.researchgate.net/publication/342646275/figure/fig4/AS:962238546464790@1606426955772/Comparison-between-LSTM-and-Bi-LSTM-networks-recreated-after-33.png" alt="Drawing"/>

# %% [markdown]
# **What is Bidirectional RNN?**
#
# A Bidirectional Recurrent Neural Network (BiRNN) is an extension of a standard RNN that processes input sequences in both forward and backward directions. This means that at each time step, the model considers both past (left-to-right) and future (right-to-left) context, leading to better performance in many sequence-related tasks, including text generation.
#
# **Why Use Bidirectional RNNs?**
#
# Bidirectional RNNs are used because they capture dependencies in the input data from both directions, which is crucial for understanding context. This makes them particularly useful in tasks like language processing, where the meaning of a word can depend on both the words that come before and after it.
#
# For example, in the sentence "The cat sat on the mat," the word "mat" is influenced by both the preceding words ("The cat sat on the") and what could potentially follow (e.g., "and looked at the mouse").
#
# Example
#
# Let's consider a sentence: "He opened the door."
#
# Simple RNN: It processes the sentence from left to right, word by word:
#
# He → opened → the → door
# Each word is processed based on the previous word.
#
# Bidirectional RNN: It processes the sentence in both directions:
#
# Forward pass: He → opened → the → door
#
# Backward pass: door → the → opened → He
#
# The output at each time step is a combination of the information from both the forward and backward passes, allowing the network to understand the context better. For instance, knowing that "door" follows "the" helps confirm that "opened" likely refers to a physical action, not a metaphorical one.

# %% [markdown]
# **Choosing the Base RNN for Bidirectional Processing:**
#
# One key flexibility of Bidirectional RNNs is that you can choose any recurrent architecture (LSTM, GRU, Simple RNN) as the base model.
#
# - Bidirectional LSTM: Best for handling long-range dependencies.
# - Bidirectional GRU: More computationally efficient than LSTM.
# - Bidirectional Simple RNN: Less commonly used due to vanishing gradient issues.
#
# Note: To determine the best base model for the Bidirectional RNN, you must evaluate the results from your previous experiments with different architectures (eg. LSTM and GRU).
#
# Review previous results from training LSTM and GRU models.
# Compare their performance in terms of:
#
# - Training time per epoch
# - Model size (number of parameters)
# - Loss and accuracy on validation data
# - Quality of generated text
#
# Based on your findings, select the best-performing model as the base architecture for the Bidirectional RNN.

# %%
def build_birnn_model(vocab_size, embedding_dim, rnn_units, batch_size, rnn_type="LSTM"):
    if rnn_type == "LSTM":
        rnn_layer = tf.keras.layers.Bidirectional(
            tf.keras.layers.LSTM(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'))
    elif rnn_type == "GRU":
        rnn_layer = tf.keras.layers.Bidirectional(
            tf.keras.layers.GRU(rnn_units, return_sequences=True, recurrent_initializer='glorot_uniform'))

    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        rnn_layer,
        tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %% [markdown]
# # Evaluating the Models

# %% [markdown]
# Model Selection

# %%
EMBEDDING_DIM = 256
RNN_UNITS = 1024
# Choose model type
model_type = "LSTM"  # Change to "GRU" or "BiLSTM"

if model_type == "LSTM":
    model = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
elif model_type == "GRU":
    model = build_gru_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
elif model_type == "BiLSTM":
    model = build_birnn_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)

print(f"Using {model_type} model for training.")
# Out:
# Using LSTM model for training.

# %% [markdown]
# Compile & Train the Model

# %%
def compile_and_train(model, path, EPOCHS = 30):
  # Define loss function
  def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

  # Compile the model
  model.compile(optimizer='adam', loss=loss)

  # Ensure checkpoint directory exists
  checkpoint_dir = f'./{path}'
  os.makedirs(checkpoint_dir, exist_ok=True)

  checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

  checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix + '.weights.h5',
    save_weights_only=True
  )

  # Train the model
  history = model.fit(
    training_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=[checkpoint_callback]
)

  return history

# %%
# Train LSTM model
model_type = "LSTM"
model = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
print(f"Training {model_type} model...")
model.summary()
history_lstm = compile_and_train(model, path="lstm_checkpoints", EPOCHS=30)
# Out:
# Training LSTM model...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 27s 139ms/step - loss: 2.4463 - val_loss: 1.9667
# Epoch 2/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 135ms/step - loss: 1.7973 - val_loss: 1.6490
# Epoch 3/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 21s 125ms/step - loss: 1.5735 - val_loss: 1.4887
# Epoch 4/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 125ms/step - loss: 1.4548 - val_loss: 1.3893
# Epoch 5/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 139ms/step - loss: 1.3801 - val_loss: 1.3272
# Epoch 6/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 134ms/step - loss: 1.3249 - val_loss: 1.2782
# Epoch 7/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 129ms/step - loss: 1.2817 - val_loss: 1.2323
# Epoch 8/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 1.2407 - val_loss: 1.1925
# Epoch 9/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 132ms/step - loss: 1.2037 - val_loss: 1.1516
# Epoch 10/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 40s 131ms/step - loss: 1.1681 - val_loss: 1.1140
# Epoch 11/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - loss: 1.1315 - val_loss: 1.0743
# Epoch 12/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 128ms/step - loss: 1.0943 - val_loss: 1.0339
# Epoch 13/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 1.0553 - val_loss: 0.9917
# Epoch 14/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 1.0149 - val_loss: 0.9450
# Epoch 15/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - loss: 0.9712 - val_loss: 0.9037
# Epoch 16/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 151ms/step - loss: 0.9280 - val_loss: 0.8535
# Epoch 17/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.8822 - val_loss: 0.8059
# Epoch 18/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.8362 - val_loss: 0.7561
# Epoch 19/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 130ms/step - loss: 0.7904 - val_loss: 0.7096
# Epoch 20/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 136ms/step - loss: 0.7451 - val_loss: 0.6669
# Epoch 21/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.6994 - val_loss: 0.6233
# Epoch 22/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.6578 - val_loss: 0.5862
# Epoch 23/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - loss: 0.6186 - val_loss: 0.5511
# Epoch 24/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - loss: 0.5813 - val_loss: 0.5127
# Epoch 25/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 132ms/step - loss: 0.5423 - val_loss: 0.4792
# Epoch 26/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 127ms/step - loss: 0.5100 - val_loss: 0.4494
# Epoch 27/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 138ms/step - loss: 0.4792 - val_loss: 0.4232
# Epoch 28/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 23s 134ms/step - loss: 0.4509 - val_loss: 0.3982
# Epoch 29/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 130ms/step - loss: 0.4268 - val_loss: 0.3780
# Epoch 30/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 0.4033 - val_loss: 0.3543

# %%
# Train GRU model
model_type = "GRU"
gru_model = build_gru_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE)
print(f"Training {model_type} model...")
gru_model.summary()
history_gru = compile_and_train(gru_model, path="gru_checkpoints", EPOCHS=30)
# Out:
# Training GRU model...
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 2.5532 - val_loss: 2.0483
# Epoch 2/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 108ms/step - loss: 1.8741 - val_loss: 1.7119
# Epoch 3/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 105ms/step - loss: 1.6282 - val_loss: 1.5298
# Epoch 4/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.4929 - val_loss: 1.4280
# Epoch 5/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 98ms/step - loss: 1.4110 - val_loss: 1.3573
# Epoch 6/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 1.3518 - val_loss: 1.3003
# Epoch 7/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - loss: 1.3053 - val_loss: 1.2537
# Epoch 8/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - loss: 1.2650 - val_loss: 1.2087
# Epoch 9/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.2264 - val_loss: 1.1717
# Epoch 10/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.1911 - val_loss: 1.1300
# Epoch 11/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 1.1532 - val_loss: 1.0911
# Epoch 12/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 1.1169 - val_loss: 1.0502
# Epoch 13/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - loss: 1.0790 - val_loss: 1.0106
# Epoch 14/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 1.0402 - val_loss: 0.9667
# Epoch 15/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.9971 - val_loss: 0.9215
# Epoch 16/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.9558 - val_loss: 0.8777
# Epoch 17/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 17s 101ms/step - loss: 0.9118 - val_loss: 0.8269
# Epoch 18/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - loss: 0.8668 - val_loss: 0.7836
# Epoch 19/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - loss: 0.8232 - val_loss: 0.7404
# Epoch 20/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 0.7805 - val_loss: 0.6957
# Epoch 21/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - loss: 0.7390 - val_loss: 0.6614
# Epoch 22/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 101ms/step - loss: 0.7027 - val_loss: 0.6371
# Epoch 23/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 104ms/step - loss: 0.6695 - val_loss: 0.5974
# Epoch 24/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 0.6395 - val_loss: 0.5698
# Epoch 25/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - loss: 0.6109 - val_loss: 0.5505
# Epoch 26/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.5889 - val_loss: 0.5247
# Epoch 27/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 0.5675 - val_loss: 0.5048
# Epoch 28/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.5490 - val_loss: 0.4934
# Epoch 29/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 0.5334 - val_loss: 0.4793
# Epoch 30/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 18s 103ms/step - loss: 0.5226 - val_loss: 0.4693

# %%
# Train Bidirectional RNN model (using LSTM as base since it performed better)
model_type = "BiLSTM"
birnn_model = build_birnn_model(VOCAB_SIZE, EMBEDDING_DIM, RNN_UNITS, BATCH_SIZE, rnn_type="LSTM")
print(f"Training {model_type} model...")
birnn_model.summary()
history_birnn = compile_and_train(birnn_model, path="birnn_checkpoints", EPOCHS=30)
# Out:
# Training BiLSTM model...
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 47s 262ms/step - loss: 0.8317 - val_loss: 0.0360
# Epoch 2/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 250ms/step - loss: 0.0299 - val_loss: 0.0262
# Epoch 3/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 258ms/step - loss: 0.0251 - val_loss: 0.0234
# Epoch 4/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 252ms/step - loss: 0.0232 - val_loss: 0.0221
# Epoch 5/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 0.0219 - val_loss: 0.0206
# Epoch 6/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 256ms/step - loss: 0.0207 - val_loss: 0.0194
# Epoch 7/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 254ms/step - loss: 0.0197 - val_loss: 0.0182
# Epoch 8/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0187 - val_loss: 0.0169
# Epoch 9/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 255ms/step - loss: 0.0172 - val_loss: 0.0151
# Epoch 10/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - loss: 0.0157 - val_loss: 0.0136
# Epoch 11/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 255ms/step - loss: 0.0140 - val_loss: 0.0110
# Epoch 12/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0117 - val_loss: 0.0087
# Epoch 13/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 257ms/step - loss: 0.0091 - val_loss: 0.0061
# Epoch 14/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 253ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 15/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 16/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 260ms/step - loss: 0.0018 - val_loss: 8.5573e-04
# Epoch 17/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 42s 254ms/step - loss: 7.5426e-04 - val_loss: 3.4986e-04
# Epoch 18/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 3.0630e-04 - val_loss: 1.9141e-04
# Epoch 19/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 255ms/step - loss: 1.8582e-04 - val_loss: 1.4531e-04
# Epoch 20/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 1.3589e-04 - val_loss: 1.0748e-04
# Epoch 21/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 1.0591e-04 - val_loss: 8.6555e-05
# Epoch 22/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 83s 259ms/step - loss: 8.6560e-05 - val_loss: 7.2139e-05
# Epoch 23/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - loss: 7.1912e-05 - val_loss: 6.1131e-05
# Epoch 24/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 6.1247e-05 - val_loss: 5.2521e-05
# Epoch 25/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 5.2396e-05 - val_loss: 4.5399e-05
# Epoch 26/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 255ms/step - loss: 4.5409e-05 - val_loss: 3.9409e-05
# Epoch 27/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - loss: 3.9581e-05 - val_loss: 3.4646e-05
# Epoch 28/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 255ms/step - loss: 3.4675e-05 - val_loss: 3.0392e-05
# Epoch 29/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 251ms/step - loss: 3.0432e-05 - val_loss: 2.6851e-05
# Epoch 30/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - loss: 2.6949e-05 - val_loss: 2.3862e-05

# %% [markdown]
# # Generate Text Using the Model

# %%
class OneStepTextGenerator(tf.keras.Model):
    def __init__(self, model, chars_from_ids, ids_from_chars, temperature=1.0):
        """
        Initializes the OneStepTextGenerator.

        Parameters:
        - model: Trained text generation model (e.g., LSTM or GRU).
        - chars_from_ids: Function mapping character IDs to characters.
        - ids_from_chars: Function mapping characters to their respective IDs.
        - temperature (float): Controls randomness in text generation.
          -> Higher temperature (> 1.0): Produces more diverse and unpredictable text.
          -> Lower temperature (< 1.0): Makes the model more confident but results in repetitive text.
          -> Temperature = 1.0: Standard behavior without biasing randomness.
        """
        super().__init__()
        self.model = model
        self.chars_from_ids = chars_from_ids
        self.ids_from_chars = ids_from_chars
        self.temperature = temperature

    def generate_text(self, start_string, num_generate=1000):
        """
        Generates text one character at a time based on a starting string.

        Parameters:
        - start_string (str): Initial text prompt.
        - num_generate (int): Number of characters to generate.

        Returns:
        - str: Generated text.
        """
        # Convert start string to tensor representation
        input_eval = tf.expand_dims(self.ids_from_chars(tf.strings.unicode_split(start_string, 'UTF-8')), 0)
        text_generated = []

        # Initial hidden state (None allows automatic initialization)
        states = None

        for _ in range(num_generate):
            # Get model predictions and hidden state
            # predictions, states = self.model(input_eval, states=states, return_state=True)
            predictions = self.model(input_eval)

            # Adjust predictions using temperature
            predictions = predictions[:, -1, :] / self.temperature

            # Sample the next character ID from a probability distribution
            predicted_id = tf.random.categorical(predictions, num_samples=1)[-1, 0].numpy()

            # Use the predicted ID as next input
            input_eval = tf.expand_dims([predicted_id], 0)

            # Convert ID back to character and append to output
            text_generated.append(self.chars_from_ids(predicted_id).numpy().decode('utf-8'))

        return start_string + ''.join(text_generated)

# %% [markdown]
# # Evaluate Model Performance

# %% [markdown]
# **1- Perplexity (PP)**
#
# TODO: Measures uncertainty in predicting next character for each model and leave the results in the Notebook.
#
# ***Lower values = better model***

# %%
def perplexity(logits, labels):
    loss = tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
    return np.exp(np.mean(loss))

def evaluate_model_perplexity(model, dataset):
    total_loss = 0.0
    total_tokens = 0

    for input_batch, label_batch in dataset:
        logits = model(input_batch, training=False)
        loss = perplexity(logits, label_batch)
        total_loss += np.log(loss)
        total_tokens += tf.size(label_batch).numpy()

    avg_loss = total_loss / total_tokens
    return np.exp(avg_loss)

# %%
print("=== Perplexity Scores ===")
lstm_perplexity = evaluate_model_perplexity(model, validation_dataset)
print(f"LSTM Perplexity: {lstm_perplexity:.4f}")

gru_perplexity = evaluate_model_perplexity(gru_model, validation_dataset)
print(f"GRU Perplexity: {gru_perplexity:.4f}")

birnn_perplexity = evaluate_model_perplexity(birnn_model, validation_dataset)
print(f"BiLSTM Perplexity: {birnn_perplexity:.4f}")
# Out:
# === Perplexity Scores ===
# LSTM Perplexity: 1.0001
# GRU Perplexity: 1.0001
# BiLSTM Perplexity: 1.0000

# %% [markdown]
# **2- Text Coherence & Fluency**
#
# Subjective evaluation by examining generated text
#
# **TODO: Generate at least 3 Samples (one from each model) and leave them in the Notebook.**

# %%
# Generate text from each model
generator_lstm = OneStepTextGenerator(model, chars_from_ids, ids_from_chars, temperature=1.0)
generator_gru = OneStepTextGenerator(gru_model, chars_from_ids, ids_from_chars, temperature=1.0)
generator_birnn = OneStepTextGenerator(birnn_model, chars_from_ids, ids_from_chars, temperature=1.0)

print("=== LSTM Generated Text ===")
print(generator_lstm.generate_text("ROMEO: ", num_generate=500))

print("\n=== GRU Generated Text ===")
print(generator_gru.generate_text("ROMEO: ", num_generate=500))

print("\n=== BiLSTM Generated Text ===")
print(generator_birnn.generate_text("ROMEO: ", num_generate=500))
# Out:
# === LSTM Generated Text ===
# ROMEO: arar hain bour goularewn thowosowitoprdshir SAENURUShouthe.
# Buror hon gofe vin, t. p!
#
# DURY:
# AnarProfonopisth liswaif t ce matester s y forotalleem thithowh yore:
# TI
# KIAgowe gheevif e:
# Con hagou wed he am woche g at Wheart h s! hood yo
# Tinobrouat.
#
# Whe t,
# ORANENG, quapel s iegh oourousld, lld yowantheyowhan I gre thofos t, hepenthodes olosousuce:
#
# ARANTouath y yo whisthaf illde e afe beag f cony;
# I lshat s; athicar mind I ancr wa haroonem scen heplit lllyofout te, EYostuchecon bl g, athe fonghy.
#
# === GRU Generated Text ===
# ROMEO: y der IOMUSCourell poon knseta ustewilif gsig nonor hotoure l ise.
# HARO:
#
# HAng has thame nghe bamas,
# AULeandanereer ours.
# A,
#
#
# HEd n RILI ncone ty the tenst sonthouivenoseandwite.
#
# D We qule irent taisthinthiscofoutaven ton,
# BURY I sper
# Th?
# YO:
# Hooterenghe:
# STENCath,
# Yore and he find d;
# ONof wicon d he t DOMa f s ce t lito ld; le,
# A:
# T:
#
# pis, owhofu g che.
#
# Pr y.
# APrderesthencamyong,
# IO:
# I he hindere gomy crul sen.
# Asuchiowinicoouloonond undanded, torooll prir
# S yone w st yofrs d nd I'd owist ES
#
# === BiLSTM Generated Text ===
# ROMEO: t thy f$chad;zO:
# Thy chadind fflfy d, dpplougareplagind:
# Gfigarvegepydwigigath mepllfffod ptrsplllarves
# Wh ffffinch gharome ffffigardfff gveffth f s gad haknowhiffopred chakkx$Jur, gachus ps
# FFFFigwagedrt pplod, VqJ--Clchy'schlvepppe, bj'd;
# CIfighaZg?YspUSchy ge my fffffouchad tighedigaphmomepZy ppppousemy sthath mad plwad gadaur'Why galffffff wintheged figodmy fugand paged ckSprclarspwhady s
# VZes plbd, d,
# FFuch, pthal,
# Ga
# BGrad, ftr stharaplakspthigmath
# Cffomow, asth ckvemprthmithedigabesis nd;

# %% [markdown]
# **3- BLEU Score**
#
# TODO: Measures similarity between generated and real text for each model and leave the results in the Notebook.

# %%
def compute_bleu(reference, generated):
    return sentence_bleu([list(reference)], list(generated))

def evaluate_model_bleu(model, dataset):
    bleu_scores = []

    for input_batch, label_batch in dataset:
        logits = model(input_batch, training=False)
        predictions = tf.argmax(logits, axis=-1)

        label_batch = label_batch.numpy()

        for pred_seq, true_seq in zip(predictions, label_batch):
            # Decode sequences to text
            pred_text = text_from_ids(pred_seq, chars_from_ids).numpy().decode('utf-8')
            true_text = text_from_ids(true_seq, chars_from_ids).numpy().decode('utf-8')

            # Compute BLEU score for each sample
            bleu = compute_bleu(true_text, pred_text)
            bleu_scores.append(bleu)

    return np.mean(bleu_scores)

# %%
print("=== BLEU Scores ===")
lstm_bleu = evaluate_model_bleu(model, validation_dataset)
print(f"LSTM BLEU Score: {lstm_bleu:.4f}")

gru_bleu = evaluate_model_bleu(gru_model, validation_dataset)
print(f"GRU BLEU Score: {gru_bleu:.4f}")

birnn_bleu = evaluate_model_bleu(birnn_model, validation_dataset)
print(f"BiLSTM BLEU Score: {birnn_bleu:.4f}")
# Out:
# === BLEU Scores ===
# LSTM BLEU Score: 0.8004
# GRU BLEU Score: 0.7069
# BiLSTM BLEU Score: 1.0000

# %% [markdown]
# # Personal Comments **

# %% [markdown]
# Results for initial trial (EMBEDDING_DIM = 256 -RNN_UNITS = 1024)
# | Model   | Perplexity | BLEU Score | Val Loss  |
# |---------|------------|------------|-----------|
# | LSTM    | 1.0001     | 0.8004     | 0.3543    |
# | GRU     | 1.0001     | 0.7069     | 0.4693    |
# | BiLSTM  | 1.0000     | 1.0000     | 0.0000239 |

# %% [markdown]
# ## Experiments

# %%
# Trial 2: Higher Embedding Dim
EMBEDDING_DIM_2 = 512
RNN_UNITS_2 = 1024
model_trial2 = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM_2, RNN_UNITS_2, BATCH_SIZE)
print("Trial 2: EMBEDDING_DIM=512, RNN_UNITS=1024")
history_trial2 = compile_and_train(model_trial2, path="lstm_trial2_checkpoints", EPOCHS=30)

# Trial 3: Higher RNN Units
EMBEDDING_DIM_3 = 256
RNN_UNITS_3 = 2048
model_trial3 = build_lstm_model(VOCAB_SIZE, EMBEDDING_DIM_3, RNN_UNITS_3, BATCH_SIZE)
print("Trial 3: EMBEDDING_DIM=256, RNN_UNITS=2048")
history_trial3 = compile_and_train(model_trial3, path="lstm_trial3_checkpoints", EPOCHS=30)
# Out:
# Trial 2: EMBEDDING_DIM=512, RNN_UNITS=1024
# Epoch 1/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - loss: 2.3728 - val_loss: 1.9099
# Epoch 2/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - loss: 1.7464 - val_loss: 1.6079
# Epoch 3/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - loss: 1.5406 - val_loss: 1.4606
# Epoch 4/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 152ms/step - loss: 1.4333 - val_loss: 1.3818
# Epoch 5/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 149ms/step - loss: 1.3659 - val_loss: 1.3133
# Epoch 6/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - loss: 1.3164 - val_loss: 1.2731
# Epoch 7/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - loss: 1.2740 - val_loss: 1.2264
# Epoch 8/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 1.2374 - val_loss: 1.1906
# Epoch 9/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 146ms/step - loss: 1.2011 - val_loss: 1.1500
# Epoch 10/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - loss: 1.1676 - val_loss: 1.1126
# Epoch 11/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 1.1323 - val_loss: 1.0754
# Epoch 12/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - loss: 1.0963 - val_loss: 1.0370
# Epoch 13/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 146ms/step - loss: 1.0588 - val_loss: 0.9953
# Epoch 14/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 149ms/step - loss: 1.0184 - val_loss: 0.9521
# Epoch 15/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.9763 - val_loss: 0.9088
# Epoch 16/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - loss: 0.9350 - val_loss: 0.8632
# Epoch 17/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.8884 - val_loss: 0.8109
# Epoch 18/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.8431 - val_loss: 0.7676
# Epoch 19/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.7973 - val_loss: 0.7190
# Epoch 20/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.7512 - val_loss: 0.6708
# Epoch 21/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.7039 - val_loss: 0.6322
# Epoch 22/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.6612 - val_loss: 0.5903
# Epoch 23/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 149ms/step - loss: 0.6197 - val_loss: 0.5510
# Epoch 24/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - loss: 0.5812 - val_loss: 0.5146
# Epoch 25/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 151ms/step - loss: 0.5434 - val_loss: 0.4799
# Epoch 26/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 150ms/step - loss: 0.5093 - val_loss: 0.4461
# Epoch 27/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 149ms/step - loss: 0.4782 - val_loss: 0.4202
# Epoch 28/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - loss: 0.4490 - val_loss: 0.3946
# Epoch 29/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - loss: 0.4245 - val_loss: 0.3712
# Epoch 30/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - loss: 0.4003 - val_loss: 0.3492
# Trial 3: EMBEDDING_DIM=256, RNN_UNITS=2048
# Epoch 1/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 70s 424ms/step - loss: 2.6199 - val_loss: 2.0725
# Epoch 2/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 1.8861 - val_loss: 1.7145
# Epoch 3/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 421ms/step - loss: 1.6175 - val_loss: 1.5102
# Epoch 4/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 422ms/step - loss: 1.4689 - val_loss: 1.3922
# Epoch 5/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 1.3763 - val_loss: 1.3142
# Epoch 6/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 427ms/step - loss: 1.3110 - val_loss: 1.2498
# Epoch 7/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 1.2550 - val_loss: 1.1911
# Epoch 8/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 1.2035 - val_loss: 1.1316
# Epoch 9/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 422ms/step - loss: 1.1489 - val_loss: 1.0682
# Epoch 10/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 1.0924 - val_loss: 1.0014
# Epoch 11/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 427ms/step - loss: 1.0282 - val_loss: 0.9286
# Epoch 12/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 425ms/step - loss: 0.9548 - val_loss: 0.8445
# Epoch 13/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 0.8748 - val_loss: 0.7585
# Epoch 14/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 421ms/step - loss: 0.7865 - val_loss: 0.6634
# Epoch 15/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 422ms/step - loss: 0.6928 - val_loss: 0.5718
# Epoch 16/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 425ms/step - loss: 0.6015 - val_loss: 0.4831
# Epoch 17/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 424ms/step - loss: 0.5124 - val_loss: 0.4048
# Epoch 18/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 425ms/step - loss: 0.4317 - val_loss: 0.3389
# Epoch 19/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 422ms/step - loss: 0.3618 - val_loss: 0.2905
# Epoch 20/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 424ms/step - loss: 0.3057 - val_loss: 0.2363
# Epoch 21/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - loss: 0.2551 - val_loss: 0.2001
# Epoch 22/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - loss: 0.2186 - val_loss: 0.1754
# Epoch 23/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 425ms/step - loss: 0.1902 - val_loss: 0.1536
# Epoch 24/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 424ms/step - loss: 0.1696 - val_loss: 0.1389
# Epoch 25/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 0.1544 - val_loss: 0.1288
# Epoch 26/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - loss: 0.1441 - val_loss: 0.1225
# Epoch 27/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - loss: 0.1386 - val_loss: 0.1213
# Epoch 28/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 68s 426ms/step - loss: 0.1406 - val_loss: 0.1263
# Epoch 29/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 423ms/step - loss: 0.1549 - val_loss: 0.1507
# Epoch 30/30
# 155/155 ━━━━━━━━━━━━━━━━━━━━ 67s 424ms/step - loss: 0.2102 - val_loss: 0.2212

# %%
print("=== Perplexity Scores for Parameter Trials ===")
trial2_perplexity = evaluate_model_perplexity(model_trial2, validation_dataset)
print(f"Trial 2 (EMBEDDING_DIM=512, RNN_UNITS=1024) Perplexity: {trial2_perplexity:.4f}")

trial3_perplexity = evaluate_model_perplexity(model_trial3, validation_dataset)
print(f"Trial 3 (EMBEDDING_DIM=256, RNN_UNITS=2048) Perplexity: {trial3_perplexity:.4f}")
# Out:
# === Perplexity Scores for Parameter Trials ===
# Trial 2 (EMBEDDING_DIM=512, RNN_UNITS=1024) Perplexity: 1.0001
# Trial 3 (EMBEDDING_DIM=256, RNN_UNITS=2048) Perplexity: 1.0000

# %%
generator_trial2 = OneStepTextGenerator(model_trial2, chars_from_ids, ids_from_chars, temperature=1.0)
generator_trial3 = OneStepTextGenerator(model_trial3, chars_from_ids, ids_from_chars, temperature=1.0)

print("=== Trial 2 Generated Text (EMBEDDING_DIM=512, RNN_UNITS=1024) ===")
print(generator_trial2.generate_text("ROMEO: ", num_generate=500))

print("\n=== Trial 3 Generated Text (EMBEDDING_DIM=256, RNN_UNITS=2048) ===")
print(generator_trial3.generate_text("ROMEO: ", num_generate=500))
# Out:
# === Trial 2 Generated Text (EMBEDDING_DIM=512, RNN_UNITS=1024) ===
# ROMEO: 'llilisind matorothowe:
#
# ICHe ived cthed t, sosthised wesicothere my, deand ye cus we te's, ger'st t, imay sind ss I
#
# PRe ave, nd fan, winiseath t gh t,
#
# TRO:
# CEn d s, itham I w y.
# SINovedurinowel thoouth,
# Tis,
# HEThiol sck.
# Oflyouiomasuiffo ho sthofischoul t sthe hiocllt! mape ave an henous e, ad An ar--pllen t the the wow be g KI
# CAs, the NGE:
#
#
#
# An yore hamee ine d! t d avath tly the'ldaro anil y dey ar! y cil I dsun, h llamyofomyownalileilombe bapralitsus,
# GOLommyowingereaiuis.
# AULon,
#
# Se gou
#
# === Trial 3 Generated Text (EMBEDDING_DIM=256, RNN_UNITS=2048) ===
# ROMEO: The weany'llle prds thaith seal fus;
# INon y, cht t chevell ben fomey heletchtcar y s so n! moupave qup wo ond viveve hanse, k brk htheme?
#
# We,
# Cirthon;
# UCobee prwins ar E:
#
# BYO:
#
# Fowoup anllll bedo des outh bllles thofoour-toncellarer,
# Hemot' tiveatlow a myomutont ar s m wowe, re VO:
# Tidll f hout nthe,
# TRil IUCAr?
# I hators wndeaukisll e?
# RIUMomo, IUSTEgomy
# Al PESik! thou br acoous, my gauk.
#
# MOLALethor, po tce?
# CAnor at, thal dakes thothenopeve ch fthelous chant to Cor wis witck s wn, ndanitha c

# %%
print("=== BLEU Scores for Parameter Trials ===")
trial2_bleu = evaluate_model_bleu(model_trial2, validation_dataset)
print(f"Trial 2 (EMBEDDING_DIM=512, RNN_UNITS=1024) BLEU Score: {trial2_bleu:.4f}")

trial3_bleu = evaluate_model_bleu(model_trial3, validation_dataset)
print(f"Trial 3 (EMBEDDING_DIM=256, RNN_UNITS=2048) BLEU Score: {trial3_bleu:.4f}")
# Out:
# === BLEU Scores for Parameter Trials ===
# Trial 2 (EMBEDDING_DIM=512, RNN_UNITS=1024) BLEU Score: 0.8013
# Trial 3 (EMBEDDING_DIM=256, RNN_UNITS=2048) BLEU Score: 0.8630
